# %% [markdown]
# ## why programming?
#
# we choose python as our programming language
# - programming languages are used to "build logic".
# - It's also used for "problem solving".
# - It is used for "application building".

# %% [markdown]
# ### why python
#
# - python has a "easy syntax".
# - It consists "less lines of code".
# - It has "more inbuilt libraries".
# - It is "easy to learn".
# - It also used for "data visualization"
# - It is a "high level programming language also support multiple paradigm, simple to learn easy to implement".

# %% [markdown]
# ### PYTHON HISTORY
# - python was invented by "Guido van Rossum".
# - He started to develop python in the year of "1989".
# - It got universal access in the year of "1991", at that time the version of python is "python 0.90".
# - in the year of "1994" python version 1.0 was invented.
# - in the year of "2000" python version 2.0 was invented.
# - in the year of "2010" python version 2.7 was invented.
# - in the year of "2008 October" python 2.6 was invented.
# - in the year of "2008 December" python 3.0 was invented.
# - in the year of "2024" python version 3.13 was invented.
# - in the year of "2020" python two versions are replicated(no longer used).
# - The name of the python was derived from "Monty python circus".

# %% [markdown]
# ### python features
#
# - It  is easy to learn.
# - It has simple syntax.
# - It  is a interpreter based language(checks line by line).
# - support multiple paradigms (procedural oriented and object oriented).
# - support object oriented programming.
# - more built-in-libraries.
# - open source programming language.
# - huge community/wide community.
# - simple to integrate with other language.
# - platform independent and dynamic typing (also called as cross platform means program can run all types of operating systems).

# %% [markdown]
# ### compiler                               v/s               interpreter
#
# - it execute source code at a time.                    Its the source code line by line.
#
# - it shows multiple errors at a time.                  It shows single error at a time.
#
# - we can solve all errors at a time.                   we can solve current line errors.
#
# - examples:-c, java , c++.                             examples:-python, php.
#
# - source file(.c,.java,.cpp)                           source file(.py,.php)

# %% [markdown]
# ### Types of  interpreters
# - cpython -written in c
# - pypy -JIT(just in time)
# - Jython-runs on JVM
# - micro python-works on IOT applications development

# %% [markdown]
# ### procedural                                         v/s                             object-oriented
#  the blocks of code is divided as functions                             the blocks of code is divided as objects
#
#  it is top-down approach                                                it is bottom-up approach
#
#  it do not support access specifier                                     it support access specifier
#
#  it is less secure                                                      it is more secure
#
#  it do not support Inheritance                                          it support inheritance
#
#  it do not support abstraction                                          it support abstraction
#
#  it do not support Encapsulation                                        it support Encapsulation
#
#  it do not support polymorphism                                         it support polymorphism
#
#  the program code is in medium in size                                  the program code is in large in size
#
#  it is used to solve small problems                                     it is used to solve complex problems
#
#  the code reusability is less                                           the code reusability is more
#
#  ex:-c, basic c, pascal                                                 ex:- c++, java, python

# %% [markdown]
# ### Applications of python
#
# - it is used in web development
# - it is used in application development
# - it also used in software development
# - it is used in Data analytics
# - it is used in Data science
# - it is used in Data visualization
# - it is used in health applications

# %% [markdown]
# ### Tokens:-
#
#  it is a small block of code/script.
#
# ### types of tokens :
#
# ### Identifiers:-
# - used to identify variables  like (class, function)
#
# ### Keywords :
# - python 3.10 version consists of 36 keywords.
# -  python 3.9 version consists of 35 keywords.
# -  python 3.7 version consists of 33 keywords.
#
# ### Literals:
# - these are the constant values
#
# ### separators(punctuations):
# - it is a symbols to separates values (coma(,),colon(:),brackets(()),square brackets([]),curly brackets({}).
#
# ### Operators:
# - it is a symbols to perform some operation on operands(variables),operators are the symbols used to perform specific task.
#
# ### some key words are:
# - if, else, print, none, int, float etc.

# %% [markdown]
# ### comments
#
# - they are two types
#     1)single line comments(#),
#     2)multiple line comments('''  ''') or ("""   """).
# - it define the code flow by this we read (or) understand the code.
# ### single line comment:
# - denoted with "#"
# example:-a=10 #initlize a value
#          b=20 #intilize a value
#          c=a+b #adding a and b
#          print(c) #printing result
# ### Multiple line comments:
# - these are represented by ('''   ''') or ("""  """)
# example:-'''this is a multiple line comment '''
# - to apply comment lines for all select+ctrl+back slash (/).

# %% [markdown]
# ### VARIBLES
# - It is used to store date (or) a place holder to store data.
# - It also perform modification and updation.
# - we can use in program.
# example:-num=10
# num=variable
# 10=data
#
# Variable naming rules:
# ------------------------
# 1)starts with letters or '_'.
# examples:-num=20, _var=30.
#
# 2)should not start with numbers but variable name contains number.
# example:- 2num=30, num2=30
#
# 3)variable names not contains special characters
#
# 4)variable names are case sensitive
# example:-Num, num(both are separate variable)
#
# 5)keywords are not consider as variables names.
#
# 6)variable name not contains space.
# example:-my number=30,my_number=30
#
# ### Multiple values, Multiple variable name:-
# num1=20
# num2=30
# string="abc"
#
# in single line :- num1,num2,string = 20,30,"string"
# values will assign for variables in position order.
#
# ### Multiple variable name and single value:-
#
# num1=10
# num2=10
# num3=10
#
# num1,num2,num3=10,10,10
#
# correct way:-num1=num2=num3=10
#
# num1,num2,num3=10(error because variables are seperated with coma)
#
# explanation:-
# ------------
# num3=10
# num3=num2
# num2=10
# num2=num1
# num1=10
#
# ### Re-assign values:-
# num1=20
# num2=num1
# num1=30
#
# ### swapping of two numbers:-
#  num1=10 num2=20 #initilizing values
# temp=num1
# num2=num1
# num2=temp (swapping of values)
#
# without temp:-
#
#       num1=10 num=20
#       num1,num2=10,20
#       num1,num2=num2,num1  (num1,num2=20,10 result after swapping of two numbers)
#
# ### Deleting a variable:-
#
#    a=10
#    b=20
#    c=30
# print(a+b)
# delete c (or) use comment lines
#
#      a=10
#      b=20
#      del a
#      print (a+b)
# O/P:-name error
#
# ### Boolean values:
#  Boolean values are (true or false) or (0,1)
#  example:-
#  - bool(0)=falsE]
#  - bool(1)=true
#  - Bool("hi")=true (here we count characters)
#  - bool(-1)=true (here the given value is not equal to zero)
#  - bool([])=false (here we taken the empty space in the brackets).
#  - bool([0])= list so it is true
#  - bool(0)=value so it is false

# %% [markdown]
# ### Type:
# - it is used to return the type of parameter.
#
# ### syntax:
# - type(parameter)
#
# ### example:-
#
# 1)
# num=input()
# 10
# print(type(num))
# <class 'str'>
# print(num)
# 10
#
# 2)
# num=input()
# hello
# print(type(num))
# <class 'str'>
# print(num)
# hello
#
# 3)
# num=int(input())
# 20
# print(type(num))
# <class 'int'>
# print(num)
# 20
#
# 4)
# num=float(input())
# 20.5
# print(type(num))
# <class 'float'>
# print(num)
# 20.5
#
# 5)
# num=str(input())
# hello
# print(type(num))
# <class 'str'>
# print(num)
# hello

# %% [markdown]
# ### Data types:-
# - they are two types
#
#        1)premitive data type
#        2)non premitive data types
#
# ### 1)premitive data types:-
# -
#    integer:-real values like 10,20,30,-40. int()
#
#    float:-decimal values like 10.45,30.33. float()
#
#    complex:-combination of real and imaginary value 10+5j. complex()
#
#    Boolean:-either true (or) false. bool()
#
# 2)non premitive data types:-
# ----------------------------
#
# ordered sequence data types are (list, tuple, string) unordered collection data types are(set, dictionary)
#
#
# list:-[1,2,3.5.'hi',2] combination of different values allows duplicate values we can add elements.
#
# tuple:-(1,2,3.5,'hi',2) combination of different values allows duplicate values we can not add elements.
#
# string:-"abc" or 'abc' or "123"
#
# set:-{1,2,3.5,'hi'} allows only unique values , denoted with curly braces.
#
# dictionary:-{key: value} values arranged based on key values ,key values are unique values can't allow duplicate values.
